# %% [markdown]
# <a href="https://colab.research.google.com/github/THELITEESHREDDY/THELITEESHREDDY/blob/main/my_python_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("OM GANESHAYA NAMAHA")
# Out:
# OM GANESHAYA NAMAHA
